# %%
1

# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
2

# %%
Num1= 10
Num2= 30
Add= Num1+Num2
print("Num1=",Num1)
print("Num2=",Num2)
print("Add=",Add)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
3

# %%
 #Body Mass Index

# %%
Weight = float(input("Enter the Weight is in kilograms (kg)"))
Height = float(input("Enter Height is in meters (m)"))
BMI=Weight/Height**2
print(BMI)
if BMI <18.5:
    print("under weight")
elif 24.9>=BMI>=18.5:
     print("normal weight")
else:
     print("over weight")
# Out:
# Enter the Weight is in kilograms (kg) 80
# Enter Height is in meters (m) 1.4
# 40.81632653061225
# over weight
