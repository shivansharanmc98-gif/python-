# %%
1.# print 'CORRECT' if i == 10

# %%
i =int(input("enter value of ten:"))
if i == 10:
    print("value:10")
    print("correct")
else:
    print("incorrect")
# Out:
# enter value of ten: 10
# value:10
# correct

# %%
2.# Check the password, using if and else

# %%
i =str(input("Enter the password:"))
if i == "HOPE@123":
    print("Your password is correct")
else:
    print("incorrect")
# Out:
# Enter the password: HOPE@123
# Your password is correct

# %%
3.# Catagory the people by their age like children, adult, citizen, senior citizen...

# %%
age=int(input("enter your age:"))
if age <18:
        print("child")
elif 30>=age>=18:
        print("adult")
elif 30<age<=59:
        print("citizen")
else:
        print("senior citizen")
# Out:
# enter your age: 70
# senior citizen

# %%
4# Find whether given number is positive or negative

# %%
num = float(input("Enter any number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter any number:  -9
# Negative

# %%
 5# Check whether the given number is divisible by 5

# %%
num = float(input("Enter a number to check: "))
if num%5==0:
    print("number is divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Enter a number to check:  9
# Not divisible by 5
