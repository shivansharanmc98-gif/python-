# %%
1# Create a class and function, and list out the items in the list

# %%
from ai_module import SubfieldsInAI
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
 # Create a function that checks whether the given number is Odd or Even

# %%
from ai_module import OddEven
OddEven.OddEven()
# Out:
# enter the number to check odd or even 45
# 45 is odd number

# %%
 # Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female

# %%
from ai_module import ElegiblityForMarriage
ElegiblityForMarriage.Elegible()
# Out:
# enter your gender male
# enter your age 45
# your gender: male
# your age: 45
# your eligible for marriage🤣🤣

# %%
# calculate the percentage of your 10th mark
from ai_module import FindPercent
FindPercent.percentage()
# Out:
# Enter marks for Subject1:  58
# Enter marks for Subject2:  56
# Enter marks for Subject3:  45
# Enter marks for Subject4:  96
# Enter marks for Subject5:  75
# Subject1 = 58
# Subject2 = 56
# Subject3 = 45
# Subject4 = 96
# Subject5 = 75
# Percentage: 66.00

# %%
#print area and perimeter of triangle using class and functions
from ai_module import triangle
triangle.triangle()
# Out:
# enter the value of height 2
# enter the value of height 4
# enter the value of Breadth 4
# Area of Triangle: 4.0
# Perimeter of Triangle: 10
